# %%
edad_usuario = 25
Edad = 30

print(edad)
print(Edad)
# Out:
# 25
# 30

# %% [markdown]
# Tipos de variable
# Enteros>

# %%
edad = 25

print(type(edad))
# Out:
# <class 'int'>

# %% [markdown]
# Punto flotante o decimales

# %%
altura = 1.84

print(type(altura))
# Out:
# <class 'float'>

# %% [markdown]
# Cadena de texto

# %%
ciudad_origen ="Buenos Aires"

print(type(ciudad_origen))
# Out:
# <class 'str'>

# %% [markdown]
# Booleanos

# %%
usuario_premium = True

print(type(usuario_premium))
# Out:
# <class 'bool'>
