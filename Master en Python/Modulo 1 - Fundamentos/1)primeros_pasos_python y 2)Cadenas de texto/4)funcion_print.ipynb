# %%
print('hola "mundo"!')
# Out:
# hola "mundo"!

# %%
nombre = "juancho"
print(nombre)
# Out:
# juancho

# %%
print("hola mundo", "mi nombre es :juancho")
# Out:
# hola mundo mi nombre es :juancho

# %%
print(3+5)
# Out:
# 8

# %%
print("hola mi nombre es", "Juancho" ,sep=",", end="!!!") #parametro de separacion y de finalizacion
# Out:
# hola mi nombre es,Juancho!!!
