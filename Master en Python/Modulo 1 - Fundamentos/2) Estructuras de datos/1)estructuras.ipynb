# %% [markdown]
# # QUe son las estructuras de datos y para que usarlas?

# %% [markdown]
# * Formas de organizar informacion eficiente para:
#     * Manipular
#     * buscar
#     * insertar datos

# %% [markdown]
# ## Ventajas
# * Hacer tareas eficientemente
# * Facil manejo de grandes cantidades de datos
# * Codigo + legible, facil de mantener
# * El desempeño depende de la estructura usada

# %% [markdown]
# ## Cuales son?
#
# * [listas]
# * {diccionarios}
# * (tuplas)
# * {conjuntos}
