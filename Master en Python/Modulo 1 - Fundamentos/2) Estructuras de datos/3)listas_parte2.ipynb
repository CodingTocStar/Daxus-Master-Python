# %% [markdown]
# ## Operadores in y not in

# %%
personajes = ["Naruto", "Luffy", "Pikachu", "Bart", "Homero", "Usopp"]

print("Gohan" in personajes)
print("Bart" in personajes)

print("Homero" not in personajes)
# Out:
# False
# True
# False

# %% [markdown]
# ## Manipulando elementos de una lista

# %% [markdown]
# ## Metodo append()
#
# Añade un elemento al final de la lista

# %%
print(personajes)
personajes.append("Maggie")
print(personajes)
# Out:
# ['Naruto', 'Luffy', 'Pikachu', 'Bart', 'Homero', 'Usopp', 'Maggie']
# ['Naruto', 'Luffy', 'Pikachu', 'Bart', 'Homero', 'Usopp', 'Maggie', 'Maggie']

# %% [markdown]
# ## Metodo insert()
#
# Lo mete en una posicion especifica de la lista

# %%
print(f"Personajes antes de aplicar el metodo insert: {personajes}")
# Out:
# Personajes antes de aplicar el metodo insert: ['Naruto', 'Luffy', 'Pikachu', 'Bart', 'Homero', 'Usopp', 'Maggie', 'Maggie']

# %%
personajes.insert(2, "Itadori")

print(f"Personajes despues de aplicar insert(): {personajes}")
# Out:
# Personajes despues de aplicar insert(): ['Naruto', 'Luffy', 'Itadori', 'Pikachu', 'Bart', 'Homero', 'Usopp', 'Maggie', 'Maggie']

# %% [markdown]
# ## Metodo count()
#
# Cuenta cuantas veces aparece un valor en la lista

# %%
lista_numeros = [12,123, 15452, 1256, 565, 12, 123, 123]

print(lista_numeros)
# Out:
# [12, 123, 15452, 1256, 565, 12, 123, 123]

# %%
print(lista_numeros.count(123))
# Out:
# 3

# %% [markdown]
# ## Metodo reverse()
# INvierte el orden de los elementos de la lista

# %%
mi_lista = [1,2,3]

mi_lista.reverse()

print(mi_lista)
# Out:
# [3, 2, 1]

# %% [markdown]
# ## Metodo sort()
# Or
